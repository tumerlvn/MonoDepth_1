# %%
# !python /home/tamerlan/Masters/thesis/datasets/nyu_depth_v2/extract_official_train_test_set_from_mat.py /home/tamerlan/Masters/thesis/datasets/nyu_depth_v2/nyu_depth_v2_labeled.mat /home/tamerlan/Masters/thesis/datasets/nyu_depth_v2/splits.mat ./NYU_Depth_V2/official_splits/
# Out:
# /home/tamerlan/Masters/thesis/datasets/nyu_depth_v2/extract_official_train_test_set_from_mat.py:84: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   test_images = set([int(x) for x in train_test["testNdxs"]])
# /home/tamerlan/Masters/thesis/datasets/nyu_depth_v2/extract_official_train_test_set_from_mat.py:85: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   train_images = set([int(x) for x in train_test["trainNdxs"]])
# 795 training images
# 654 test images
# reading /home/tamerlan/Masters/thesis/datasets/nyu_depth_v2/nyu_depth_v2_labeled.mat
# processing images
# image 1 / 1449
# image 2 / 1449
# image 3 / 1449
# image 4 / 1449
# ...
