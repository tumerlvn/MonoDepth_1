# %%
# @title 💻 1.1 Check CUDA and Python Version (tested with CUDA 12.2 + Python 3.10.12)

# This notebook is supposed to be connected to NVIDIA drivers with CUDA.
# If this doesn't load check that GPU is selected as hardware accelerator under Edit -> Notebook settings.
# !nvidia-smi
# !python -V
# Out:
# Thu Mar 13 07:29:13 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Python 3.11.11

# %%
# @title 1.2 👆 Select Checkpoint
# !pip install ipywidgets==7.7.1 --quiet

from IPython.display import display
import ipywidgets as widgets
import shutil

ckpt_dic = {
    "Original (higher quality)": "prs-eth/marigold-v1-0",
    "LCM (faster)": "prs-eth/marigold-lcm-v1-0",
}

ckpt_name = 'LCM (faster)'
ckpt_path = ckpt_dic[ckpt_name]
w = widgets.Dropdown(
    options=['Original (higher quality)', 'LCM (faster)'],
    value=ckpt_name,
    description='Checkpoint:',
)


def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        ckpt_name = change['new']
        ckpt_path = ckpt_dic[ckpt_name]
        # print(f"Change to checkpoint: {ckpt_name} ({ckpt_path})")

w.observe(on_change)

display(w)
# print(f"{ckpt_path = }")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.5 MB/s eta 0:00:00
# Dropdown(description='Checkpoint:', index=1, options=('Original (higher quality)', 'LCM (faster)'), value='LCM…

# %% [markdown]
# ## 1.3 🏗️ Installation and Initialization
#
# We provide two ways to run the pipeline. You can choose either ONE to run:

# %% [markdown]
# ### 🅱 1.3-A Using code from the [full repository](https://github.com/prs-eth/marigold)

# %%
# @title 📦 i. Clone repository

# %%shell
cd /content

if [ -d "Marigold" ]; then
    cd Marigold
    git pull
else
    git clone https://github.com/prs-eth/Marigold.git
    cd Marigold
fi
# Out:
# Cloning into 'Marigold'...
# remote: Enumerating objects: 633, done.
# remote: Counting objects: 100% (263/263), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 633 (delta 218), reused 152 (delta 152), pack-reused 370 (from 2)
# Receiving objects: 100% (633/633), 5.70 MiB | 22.80 MiB/s, done.
# Resolving deltas: 100% (371/371), done.

# %%
# @title 🔨 ii. Install dependencies (might take minutes)
# %%shell

cd /content/Marigold

# pip install -r requirements.txt --upgrade  --quiet
pip install accelerate diffusers matplotlib scipy torch transformers --quiet

# for progress bar
pip install ipywidgets==7.7.1 --quiet

pip install -r requirements+.txt -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.0 MB/s eta 0:00:00
# Collecting omegaconf (from -r requirements+.txt (line 1))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r requirements+.txt (line 2)) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from -r requirements+.txt (line 3)) (0.9.0)
# Requirement already satisfied: accelerate>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: diffusers>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.32.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (1.14.1)
# Collecting torch==2.4.0 (from -r requirements.txt (line 5))
#   Downloading torch-2.4.0-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.19.0 (from -r requirements.txt (line 6))
#   Downloading torchvision-0.19.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: transformers>=4.32.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (4.48.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0->-r requirements.txt (line 5)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0->-r requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0->-r requirements.txt (line 5)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0->-r requirements.txt (line 5)) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.0->-r requirements.txt (line 5)) (9.1.0.70)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch==2.4.0->-r requirements.txt (line 5))
#   Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.19.0->-r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.19.0->-r requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.0->-r requirements.txt (line 5)) (12.4.127)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->-r requirements+.txt (line 1))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf->-r requirements+.txt (line 1)) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements+.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements+.txt (line 2)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements+.txt (line 2)) (2025.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.22.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.22.0->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.22.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.22.0->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.25.0->-r requirements.txt (line 2)) (8.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.25.0->-r requirements.txt (line 2)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.25.0->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 3)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.32.1->-r requirements.txt (line 7)) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.32.1->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements+.txt (line 2)) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers>=0.25.0->-r requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.4.0->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers>=0.25.0->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers>=0.25.0->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers>=0.25.0->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers>=0.25.0->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.4.0->-r requirements.txt (line 5)) (1.3.0)
# Downloading torch-2.4.0-cp311-cp311-manylinux1_x86_64.whl (797.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 1.6 MB/s eta 0:00:00
# Downloading torchvision-0.19.0-cp311-cp311-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 105.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 109.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 89.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 55.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.7 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.4 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.3 MB/s eta 0:00:00
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=233b83488beb9a93aa041267cb4a8abe061b0daabc35598068b086faaab2e3d1
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, triton, omegaconf, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 torch-2.4.0 torchvision-0.19.0 triton-3.0.0

# %%
# @title 🔧 iii. Setup directories

import os

# Directories
repo_dir = "/content/Marigold"
input_dir = os.path.join(repo_dir, "input")
output_dir = os.path.join(repo_dir, "output")
output_dir_color = os.path.join(output_dir, "depth_colored")
output_dir_tif = os.path.join(output_dir, "depth_bw")
output_dir_npy = os.path.join(output_dir, "depth_npy")

os.chdir(repo_dir)

# %%
# @title 🏇 iv. Initialize pipeline

# change model cache directory
# !export HF_HOME=/content/Marigold/checkpoint

from marigold import MarigoldPipeline

pipe = MarigoldPipeline.from_pretrained(ckpt_path)

pipe = pipe.to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/633 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.85k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/824 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/611 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# Path to the zip file in your Google Drive
zip_file_path = '/content/drive/My Drive/datasets/middlebury_processed.zip'

# Destination folder where you want to unzip the files
unzip_path = '/content/middlebury_processed/'

# Unzipping the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(unzip_path)

# Now you can load the dataset from the unzipped directory
import os
print(os.listdir(unzip_path))
# Out:
# ['middlebury_processed']

# %%
# copy files from local to colab
zip_file_path = '/content/drive/My Drive/datasets/middlebury_colab_files.zip'
unzip_path = '/content/middlebury_colab_files/'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(unzip_path)

print(os.listdir(unzip_path))
# Out:
# ['middlebury_colab_files']

# %%
# %%shell
#
# mv /content/middlebury_colab_files/middlebury_colab_files/middlebury /content/Marigold/data_split/

# %%
# %%shell
#
# mv /content/middlebury_colab_files/middlebury_colab_files/71_infer_middlebury.sh /content/Marigold/script/eval/
# mv /content/middlebury_colab_files/middlebury_colab_files/72_eval_middlebury.sh /content/Marigold/script/eval/

# %%
# %%shell
#
# mv /content/middlebury_colab_files/middlebury_colab_files/data_middlebury_test.yaml /content/Marigold/config/dataset/

# %%
# %%shell
#
# mv /content/middlebury_colab_files/middlebury_colab_files/middlebury_dataset.py /content/Marigold/src/dataset/

# %%
# %%shell
#
# export BASE_DATA_DIR="/content/middlebury_processed"
#
# bash script/eval/71_infer_middlebury.sh
# Out:
# + ckpt=prs-eth/marigold-v1-0
# + subfolder=eval
# + python infer.py --checkpoint prs-eth/marigold-v1-0 --seed 1234 --base_data_dir /content/middlebury_processed --denoise_steps 10 --ensemble_size 1 --processing_res 256 --dataset_config config/dataset/data_middlebury_test.yaml --output_dir output/eval/middlebury_test/prediction
# 2025-03-13 08:11:02.394922: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741853462.428181   12653 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741853462.438263   12653 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# arguments: Namespace(checkpoint='prs-eth/marigold-v1-0', dataset_config='config/dataset/data_middlebury_test.yaml', base_data_dir='/content/middlebury_processed', output_dir='output/eval/middlebury_test/prediction', denoise_steps=10, ensemble_size=1, half_precision=False, processing_res=256, output_processing_res=False, resample_method='bilinear', seed=1234)
# INFO:root:Inference settings: checkpoint = `prs-eth/marigold-v1-0`, with denoise_steps = 10, ensemble_size = 1, processing resolution = 256, seed = 1234; dataset config = `config/dataset/data_middlebury_test.yaml`.
# The directory 'output/eval/middlebury_test/prediction' already exists. Are you sure to continue? (y/n): y
# INFO:root:output dir = output/eval/middlebury_test/prediction
# INFO:root:device = cuda
# Loading pipeline components...: 100% 5/5 [00:01<00:00,  2.61it/s]
# INFO:root:scale_invariant: True, shift_invariant: True
# Inferencing on middlebury_test_full:   0% 0/24 [00:00<?, ?it/s]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/artroom1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:   4% 1/24 [00:03<01:18,  3.40s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/artroom2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:   8% 2/24 [00:04<00:47,  2.18s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/bandsaw1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  12% 3/24 [00:06<00:37,  1.78s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/bandsaw2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  17% 4/24 [00:07<00:32,  1.64s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/chess1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  21% 5/24 [00:08<00:29,  1.53s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/chess2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  25% 6/24 [00:10<00:25,  1.43s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/chess3/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  29% 7/24 [00:11<00:23,  1.37s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/curule1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  33% 8/24 [00:12<00:20,  1.31s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/curule2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  38% 9/24 [00:13<00:19,  1.29s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/curule3/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  42% 10/24 [00:14<00:17,  1.26s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/ladder1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  46% 11/24 [00:16<00:16,  1.25s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/ladder2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  50% 12/24 [00:17<00:15,  1.25s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/octogons1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  54% 13/24 [00:18<00:13,  1.25s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/octogons2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  58% 14/24 [00:19<00:12,  1.25s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/pendulum1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  62% 15/24 [00:21<00:11,  1.28s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/pendulum2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  67% 16/24 [00:22<00:10,  1.31s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/podium1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  71% 17/24 [00:23<00:08,  1.27s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/skates1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  75% 18/24 [00:24<00:07,  1.26s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/skates2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  79% 19/24 [00:26<00:06,  1.25s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/skiboots1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  83% 20/24 [00:27<00:04,  1.23s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/skiboots2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  88% 21/24 [00:28<00:03,  1.23s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/skiboots3/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  92% 22/24 [00:29<00:02,  1.22s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/traproom1/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full:  96% 23/24 [00:31<00:01,  1.23s/it]WARNING:root:Existing file: 'output/eval/middlebury_test/prediction/traproom2/pred_0001.npy' will be overwritten
# Inferencing on middlebury_test_full: 100% 24/24 [00:32<00:00,  1.35s/it]

# %%
# %%shell
# export BASE_DATA_DIR="/content/middlebury_processed"
#
# bash script/eval/72_eval_middlebury.sh
# Out:
# + subfolder=eval
# + python eval.py --base_data_dir /content/middlebury_processed --dataset_config config/dataset/data_middlebury_test.yaml --alignment least_square --prediction_dir output/eval/middlebury_test/prediction --output_dir output/eval/middlebury_test/eval_metric
# Evaluating: 100% 24/24 [00:10<00:00,  2.29it/s]

# %%
# !zip -r middlebury_test_10_1_256.zip /content/Marigold/output/eval/middlebury_test
# Out:
#   adding: content/Marigold/output/eval/middlebury_test/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/eval_metric/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/eval_metric/per_sample_metrics.csv (deflated 51%)
#   adding: content/Marigold/output/eval/middlebury_test/eval_metric/eval_metrics-least_square.txt (deflated 66%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/curule3/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/curule3/pred_0001.npy (deflated 12%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skiboots2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skiboots2/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/ladder2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/ladder2/pred_0001.npy (deflated 14%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/artroom1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/artroom1/pred_0001.npy (deflated 15%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/traproom1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/traproom1/pred_0001.npy (deflated 12%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/ladder1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/ladder1/pred_0001.npy (deflated 12%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/octogons1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/octogons1/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/pendulum2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/pendulum2/pred_0001.npy (deflated 14%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/curule1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/curule1/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/artroom2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/artroom2/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skates1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skates1/pred_0001.npy (deflated 14%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/traproom2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/traproom2/pred_0001.npy (deflated 14%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/curule2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/curule2/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skiboots3/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skiboots3/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/chess1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/chess1/pred_0001.npy (deflated 12%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/pendulum1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/pendulum1/pred_0001.npy (deflated 16%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/chess2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/chess2/pred_0001.npy (deflated 14%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skates2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skates2/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/chess3/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/chess3/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/bandsaw1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/bandsaw1/pred_0001.npy (deflated 12%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/bandsaw2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/bandsaw2/pred_0001.npy (deflated 12%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/octogons2/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/octogons2/pred_0001.npy (deflated 13%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/podium1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/podium1/pred_0001.npy (deflated 15%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skiboots1/ (stored 0%)
#   adding: content/Marigold/output/eval/middlebury_test/prediction/skiboots1/pred_0001.npy (deflated 13%)

# %%
# !dir
# Out:
# config		  infer.py			output		    script
# CONTRIBUTING.md   LICENSE.txt			README.md	    src
# data_split	  marigold			requirements++.txt  train.py
# doc		  middlebury_test_10_1_256.zip	requirements+.txt
# environment.yaml  middlebury_test_15_2_512.zip	requirements.txt
# eval.py		  middlebury_test_50_5_512.zip	run.py

# %%
# !cp middlebury_test_10_1_256.zip /content/drive/MyDrive/
